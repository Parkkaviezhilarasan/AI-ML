# %%
import pandas as pd
data=pd.read_csv('archive (3).zip',compression='zip')
print(data.head())

print("SHAPE:",data.shape)

print(data['Class'].value_counts())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
# SHAPE: (284807, 31)
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data.isnull().sum()
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
x=data.drop('Class',axis=1)
y=data['Class']
print(y.value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

model=DecisionTreeClassifier(random_state=42,class_weight='balanced')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(
    max_depth=6,
    min_samples_split=50,
    min_samples_leaf=20,
    class_weight='balanced',
    random_state=42
)

dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=6,
#                        min_samples_leaf=20, min_samples_split=50,
#                        random_state=42)

# %%
print("Train class distribution:")
print(y_train.value_counts())

print("\nTest class distribution:")
print(y_test.value_counts())
# Out:
# Train class distribution:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
#
# Test class distribution:
# Class
# 0    56864
# 1       98
# Name: count, dtype: int64

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_auc_score
)

y_pred = dt.predict(x_test)
y_prob = dt.predict_proba(x_test)[:, 1]

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# Confusion Matrix:
# [[55516  1348]
#  [   13    85]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.87      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.92      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# ROC-AUC Score: 0.9122595946791772

# %%
import pandas as pd

new_transaction = pd.DataFrame({
    'Time': [5.0],
    'V1': [-1.20],
    'V2': [0.30],
    'V3': [1.50],
    'V4': [0.50],
    'V5': [-0.20],
    'V6': [0.40],
    'V7': [0.20],
    'V8': [0.10],
    'V9': [-0.25],
    'V10': [0.30],
    'V11': [-0.10],
    'V12': [0.50],
    'V13': [0.20],
    'V14': [-0.10],
    'V15': [0.15],
    'V16': [-0.05],
    'V17': [0.40],
    'V18': [-0.20],
    'V19': [0.30],
    'V20': [0.10],
    'V21': [-0.05],
    'V22': [0.20],
    'V23': [-0.10],
    'V24': [0.05],
    'V25': [0.12],
    'V26': [-0.18],
    'V27': [0.13],
    'V28': [-0.02],
    'Amount': [150.0]
})
prediction = dt.predict(new_transaction)
print("Predicted Class:", prediction[0])
probability = dt.predict_proba(new_transaction)
print("Probability (Normal, Fraud):", probability[0])
# Out:
# Predicted Class: 0
# Probability (Normal, Fraud): [0.98961265 0.01038735]
